# %% [markdown]
# IMPORTS

# %%
import pandas as pd

# %%
shark_attacks = pd.read_csv("./data/attacks.csv", encoding="latin1")
shark_attacks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# TABLE INFO

# %%
print(shark_attacks.shape)
print(shark_attacks.columns)
# Out:
# (25723, 24)
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# VALUES INFO

# %%
print(shark_attacks.dtypes)
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %% [markdown]
# COHESIVENESS OF DATA

# %%
print(shark_attacks.isna().sum())
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %% [markdown]
# Extract lenght of the shark out of the column Species (3m, 4 m, 6')
# shark attacks by area in order to locate the most dangerous ones
#
# Which shark species are most dangerous? -> find the shark by injury, classify species by level of injury. (barplot of type of injuries (fatal) and hue of species)
#
# YES - Evolution of shark attacks through years.
#
# NO - When are the sharks more active? Morning, afternoon, night?... (NO SE PUEDE, LA MITAD DE LA DATA ES UNKNOWN)
#
# YES - Which is the most common activity where there were most shark attacks.
#
# YES - Dispersion of attacks through ages/sex. (dumbness of young people)
#
# NO - In which country are more attacks of sharks.
#
# NO - Which is the most common type of shark attack by country.
#
# YES - Men are most likely to provoke a shark attack.
